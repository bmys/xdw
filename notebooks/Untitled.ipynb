# %% [markdown]
# # Preprocessing DOS

# %%
# !ls ../data
# Out:
# dos.json  normal.json

# %%
import pandas as pd

# %%
dos = pd.read_json('../data/dos.json')

# %%
dos.sample(5)
# Out:
#       IP_len direction  frequency  len2  port_open protocol  service  ttl
# 3253      40        IN       4904    20         45      TCP  unknown   21
# 1490      40        IN       3141    20         45      TCP  unknown   21
# 1902      40        IN       3553    20         45      TCP  unknown   21
# 190       40        IN       1841    20         45      TCP  unknown   21
# 297       40        IN       1948    20         45      TCP  unknown   21

# %%
normal = pd.read_json('../data/normal.json')
normal.sample(5)
# Out:
#        IP_len direction  frequency  len2  port_open protocol  service  ttl
# 6098       53        IN        302    33      49572      UDP  unknown   64
# 11239      52        IN        192    32        443      TCP    https  121
# 12416      83        IN         50    63        443      TCP    https   57
# 10119    1500        IN       1879  1480        443      TCP    https   58
# 9875     1500        IN       1639  1480        443      TCP    https   58

# %%
normal.service.unique()
# Out:
# array(['ntp', 'unknown', 'domain', 'http', 'https'], dtype=object)

# %%
normal.protocol.unique()
# Out:
# array(['UDP', 'TCP'], dtype=object)

# %%
dos.service.unique()
# Out:
# array(['unknown'], dtype=object)

# %% [markdown]
# # Set labels

# %%
dos['label'] = 'dos'

# %%
dos.sample(5)
# Out:
#       IP_len direction  frequency  len2  port_open protocol  service  ttl  \
# 2295      40        IN       3946    20         45      TCP  unknown   21
# 952       40        IN       2603    20         45      TCP  unknown   21
# 1584      40        IN       3235    20         45      TCP  unknown   21
# 2712      40        IN       4363    20         45      TCP  unknown   21
# 515       40        IN       2166    20         45      TCP  unknown   21
#
#      label
# 2295   dos
# 952    dos
# 1584   dos
# 2712   dos
# 515    dos

# %%
normal['label'] = 'normal'
normal.sample(5)
# Out:
#        IP_len direction  frequency  len2  port_open protocol service  ttl  \
# 12383      52        IN         22    32        443      TCP   https  120
# 7240     1440        IN        238  1420        443      TCP   https   88
# 11543     273        IN         40   253        443      TCP   https   56
# 8236     1500        IN        998  1480        443      TCP   https   58
# 5182     1500        IN        101  1480        443      TCP   https   58
#
#         label
# 12383  normal
# 7240   normal
# 11543  normal
# 8236   normal
# 5182   normal

# %%
len(normal)
# Out:
# 12810

# %%
len(dos)
# Out:
# 3293

# %%
dos_sample = dos.sample(500)
dos_sample.sample(20)
# Out:
#       IP_len direction  frequency  len2  port_open protocol  service  ttl  \
# 2436      40        IN       4087    20         45      TCP  unknown   21
# 2498      40        IN       4149    20         45      TCP  unknown   21
# 794       40        IN       2445    20         45      TCP  unknown   21
# 2409      40        IN       4060    20         45      TCP  unknown   21
# 3138      40        IN       4789    20         45      TCP  unknown   21
# 1793      40        IN       3444    20         45      TCP  unknown   21
# 897       40        IN       2548    20         45      TCP  unknown   21
# 2397      40        IN       4048    20         45      TCP  unknown   21
# 1256      40        IN       2907    20         45      TCP  unknown   21
# 36        40        IN       1687    20         45      TCP  unknown   21
# 202       40        IN       1853    20         45      TCP  unknown   21
# 1435      40        IN       3086    20         45      TCP  unknown   21
# 659       40        IN       2310    20         45      TCP  unknown   21
# 3025      40        IN       4676    20         45      TCP  unknown   21
# 199       40        IN       1850    20         45      TCP  unknown   21
# 926       40        IN       2577    20         45      TCP  unknown   21
# 3075      40        IN       4726    20         45      TCP  unknown   21
# 719       40        IN       2370    20         45      TCP  unknown   21
# 1668      40        IN       3319    20         45      TCP  unknown   21
# 3193      40        IN       4844    20         45      TCP  unknown   21
#
#      label
# 2436   dos
# 2498   dos
# 794    dos
# 2409   dos
# 3138   dos
# 1793   dos
# 897    dos
# 2397   dos
# 1256   dos
# 36     dos
# 202    dos
# 1435   dos
# 659    dos
# 3025   dos
# 199    dos
# 926    dos
# 3075   dos
# 719    dos
# 1668   dos
# 3193   dos

# %%
normal_sample = normal.sample(500)
normal_sample.sample(20)
# Out:
#        IP_len direction  frequency  len2  port_open protocol service  ttl  \
# 12419      52        IN         15    32        443      TCP   https  120
# 11921    1500        IN       3542  1480        443      TCP   https   58
# 12365      83        IN         15    63        443      TCP   https   53
# 3805     1500        IN       1198  1480        443      TCP   https   57
# 2310     1500        IN        604  1480        443      TCP   https   57
# 854      1500        IN         70  1480        443      TCP   https   57
# 11163    1500        IN       2849  1480        443      TCP   https   58
# 7182     1440        IN        190  1420        443      TCP   https   88
# 8717     1440        IN        430  1420        443      TCP   https   88
# 7220       87        IN        220    67        443      TCP   https   88
# 7355     1440        IN        297  1420        443      TCP   https   88
# 11104    1500        IN       2800  1480        443      TCP   https   58
# 6412     1500        IN         86  1480        443      TCP   https   51
# 2882     1500        IN        535  1480        443      TCP   https   57
# 7510     1500        IN          2  1480        443      TCP   https   46
# 9726     1500        IN       1497  1480        443      TCP   https   58
# 8173     1500        IN        936  1480        443      TCP   https   58
# 4589      100        IN        213    80         53      UDP  domain   64
# 1703       52        IN         14    32         80      TCP    http   58
# 4578       52        IN        303    32        443      TCP   https  121
#
#         label
# 12419  normal
# 11921  normal
# 12365  normal
# 3805   normal
# 2310   normal
# 854    normal
# 11163  normal
# 7182   normal
# 8717   normal
# 7220   normal
# 7355   normal
# 11104  normal
# 6412   normal
# 2882   normal
# 7510   normal
# 9726   normal
# 8173   normal
# 4589   normal
# 1703   normal
# 4578   normal

# %%
data= pd.concat([dos_sample, normal_sample])
data.sample(20)
# Out:
#        IP_len direction  frequency  len2  port_open protocol  service  ttl  \
# 12498      64        IN         18    44        443      TCP    https  120
# 3209     1500        IN        745  1480        443      TCP    https   57
# 7921      995        IN        686   975        443      TCP    https   58
# 3193       40        IN       4844    20         45      TCP  unknown   21
# 9532     1500        IN       1328  1480        443      TCP    https   58
# 10495    1500        IN       2238  1480        443      TCP    https   58
# 384        40        IN       2035    20         45      TCP  unknown   21
# 7118     1440        IN        131  1420        443      TCP    https   88
# 6412     1500        IN         86  1480        443      TCP    https   51
# 2993       40        IN       4644    20         45      TCP  unknown   21
# 2201       40        IN       3852    20         45      TCP  unknown   21
# 439      1476        IN         41  1456        443      TCP    https   52
# 12419      52        IN         15    32        443      TCP    https  120
# 1317       40        IN       2968    20         45      TCP  unknown   21
# 9025     1500        IN       1642  1480        443      TCP    https   57
# 7510     1500        IN          2  1480        443      TCP    https   46
# 1104       40        IN       2755    20         45      TCP  unknown   21
# 1867       87        IN        138    67         53      UDP   domain   64
# 11852    1500        IN       3480  1480        443      TCP    https   58
# 2941       40        IN       4592    20         45      TCP  unknown   21
#
#         label
# 12498  normal
# 3209   normal
# 7921   normal
# 3193      dos
# 9532   normal
# 10495  normal
# 384       dos
# 7118   normal
# 6412   normal
# 2993      dos
# 2201      dos
# 439    normal
# 12419  normal
# 1317      dos
# 9025   normal
# 7510   normal
# 1104      dos
# 1867   normal
# 11852  normal
# 2941      dos
